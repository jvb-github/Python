# %% [markdown]
# # Python für Anfänger
# Jede dieser Zellen enthält ausfürbare Code schleifen. Diese können mit der Tasten-Kombination **Strg+Enter** ausgeführt werden. Wenn man keine Tastatur zur Hand hat, kann man auch die Zelle auswählen und sie mit Hilfe der **Run** Taste ausführen.

# %% [markdown]
# # 1. Worum geht es hier ?
# Sicher haben Sie schon solche Schlagzeilen gelesen wie "Deutschland - eine alternde Gesellschaft" oder "Die Deutschen sterben aus!". Solche Schlagzeilen beruhen auf Simulationen, die die weitere Entwicklung der Population in Deutschland berechnen.
#
# Im Internet findet man zahlreiche Simulationen zur Populationsentwicklung in Deutschland; siehe z.B. die Entwicklung der Alterspyramide. Diese Simulation verdeutlicht sehr gut, wie sich die Altersverteilung in der Population im Laufe der nächsten Jahre verändern wird.
#
# Wir werden uns im Folgenden mit der Simulation von Populationen beschäftigen. Dabei werden wir zunächst nicht die eher komplexe Population in Deutschland betrachten, sondern uns eine recht einfach konstruierte Mäusepopulation vornehmen. Ziel ist es, mit Hilfe automatisierter Berechnungen die Größe und Zusammensetzung einer sich fortpflanzenden Mäusepopulation vorherzusagen.
#
# Im Folgenden soll die Entwicklung einer Mäusepopulation untersucht werden. Differenzierte Ergebnisse erhält man, wenn man die Population in Altersklassen aufteilt. Hier bietet sich eine grobe Aufteilung in junge, erwachsene und alte Mäuse an.

# %% [markdown]
# ## 1.1 Ein einfaches Populationsmodell
# Wir betrachten das folgende einfache, an wissenschaftlichen Modellen angelehnte Fortpflanzungsmodell.
# ![populationsmopdell.png](attachment:populationsmopdell.png)
#
# - In jedem Schritt erfolgt ein Wechsel der Altersklasse: Junge Mäuse werden erwachsen, erwachsene werden alt (und alte Mäuse leider nicht mehr jung). Allerdings werden nicht alle jungen Mäuse erwachsen. Nur ein bestimmter Anteil, der nach dem Diagramm genau die Hälfte beträgt, erreicht die nächste Altersstufe. Die anderen Mäuse sterben (leider). Ebenso werden laut Diagramm nur ein Drittel der erwachsenen Mäuse auch wirklich alt.
#
#
# - Im Diagramm sind zusätzlich die Geburtenraten eingetragen. Wir gehen davon aus, dass in jedem Schritt jede erwachsene Maus im Durchschnitt vier junge Mäuse erzeugt und dass jede alte Maus im Durchschnitt zwei junge Mäuse erzeugt.

# %% [markdown]
# ### Aufgabe 1
# Wenn zu Beginn der Simulation 6 junge, 9 erwachsene und 12 alte Mäuse leben, dann pflanzt sich diese Population wie folgt fort:
# ![tabelle1.png](attachment:tabelle1.png)
# Berechnen Sie die fehlenden Werte. Sie können dazu das folgende Eingabefeld nutzen, oder die Werte anderweitig berechnen. Nennen Sie Herrn von Bargen die entsprechenden Werte bevor Sie weiter arbeiten.
#
# *Zur Kontrolle: Nach 5 Schritten besteht die gesamte Population aus knapp 300 Mäusen.*

# %%
# Dieses Feld können Sie zur Rechnung nutzen.

# %% [markdown]
# ### Aufgabe 2: Automatisierung des Modells
# Nun sollen Sie das o.g. Modell automatisieren. Hierzu nutzen Sie die unten stehende Entwicklungsumgebung.
# 1. Definieren Sie Variablen zu den drei Altersklassen (jung, erwachsen, alt) und geben Sie diesen die oben angeführten Werte.
# 2. Definieren Sie nun die Variablen neu unter Berücksichtigung der mathematischen Zusammenhänge (z.B. `erwachsen = jung // 2`)
# 3. Lassen Sie Sich die entsprechenden Werte mit Hilfe der `print` Funktion ausgeben.

# %%
# Geben Sie hier Ihren Code ein

# %% [markdown]
# Prüfen Sie Ihre Berechnungen. Nach dem ersten Schritt sollten es 60 junge, 30 erwachsene und 10 alte Mäuse sein.
#
#
# **Tipp**: Nutzen Sie weitere Hilfvariablen, um noch benötigte Zahlenwerte zwischenzuspeichern

# %%
# Schreiben Sie hier ihr geändertes Programm und kommentieren Sie die Schritte.

# %% [markdown]
# ### Aufgabe 3: Weiterführende Berechnungen.
# 1. Die Gesamtzahl der Mäuse soll nun auch verwaltet werden. Führen Sie hierzu geeignete Variablen und Berechnungen ein.
# 2. Bisher berechnet das Programm mit Hilfsvaraiblen den Populationsstand nach einem Schritt. Passen Sie ihr Programm so an, dass nun alle fünf Schritte berechnet werden können.
# 3. Sie sollen nun auch die entsprechende Schrittzahl verwalten. Integrieren Sie einen passenden Schrittzähler an geeigneter Stelle.
#
# ``schritt = 0``
#
# ``schritt = schritt + 1``

# %%
# Schreiben Sie hier das vollständige Programm.

# %% [markdown]
# ## 1.2 Trace- Tabellen und Zuordnungen
# Eine Trace-Tabelle protokolliert die Veränderungen von Variablenzuständen, wenn mehrere Zuweisungen (bzw. sonstige Anweisungen) ausgeführt werden. Das folgende Beispiel zeigt eine solche Trace-Tabelle.
# ![trace_tabelle.png](attachment:trace_tabelle.png)

# %% [markdown]
# ### Zurodnungen
# Die Ausführung einer Zuweisung erfolgt nach folgendem Schema:
# ![zuordnung.png](attachment:zuordnung.png)
#
# Schritt 1: Der Wert des Terms wird mit Hilfe des aktuellen Variablenzustands ermittelt.
#
# Schritt 2: Der Variablen, die auf der linken Seite der Zuweisung steht, wird der ermittelte Wert des Terms als neuer Wert zugeordnet.
#
# Beachten Sie, dass das Gleichheitszeichen "=" hier nicht die Gleichheit von Werten beschreibt, sondern dazu führt, dass der Variablen auf der linken Seite ein (neuer) Wert zugewiesen wird.
#
# ### Aufgabe 4: Beispiele für Zuweisungen
#  Die folgenden Beispiele verdeutlichen, wie die Werte von Variablen mit Hilfe von Zuweisungen verändert werden können. Gehen Sie die Beispiele durch und ergänze jeweils den neuen Variablenzustand in einem Kommentar. Beschreiben Sie den durchgeführten Vorgang.
#
# (a) Beispiel 1:
#
# ``{jung -> 6}
# jung = 8
# {jung -> ...}``

# %%
# Welchen Wert nimmt die Variable an und warum?

# %% [markdown]
# (b) Beispiel 2:
#
# ``{}
# hilf = 3
# {hilf -> ...}``

# %%
# Welchen Wert nimmt die Variable an und warum?

# %% [markdown]
#  (c) Beispiel 3:
#
#  ``{jung -> 6}
# hilf = jung
# {jung -> ...; hilf -> ...}``

# %%
# Welchen Wert nimmt die Variable an und warum?

# %% [markdown]
# (d) Beispiel 4:
#
# ``{jung -> 6; erwachsen -> 9; alt -> 12}
# hilf = erwachsen*4 + alt*2
# {jung -> ...; erwachsen -> ...; alt -> ...; hilf -> ...}``

# %%
# Welchen Wert nimmt die Variable an und warum?

# %% [markdown]
# (e) Beispiel 5:
#
# ``{schritt -> 0}
# schritt = schritt + 1
# {schritt -> ...}``

# %%
# Welchen Wert nimmt die Variable an und warum?

# %% [markdown]
# ### Aufgabe 5: Trace-Tabelle und Variablenbezeichner
# Gegeben ist der folgende Python-Dialog:
#
# ``
# a = 20
# b = 12
# c = a + b
# d = a
# a = a // 2 + 4 * b
# b = d // 2 + b // 2
# c = a + b
# d = a
# a = a // 2 + 4 * b
# b = d // 2 + b // 2
# c = a + b``
#
# 1. Erstellen Sie mit Hilfe einer Tabellenkalkulation oder eines Textverabeitungsprogramms eine Trace-Tabelle.
# 2. Die Folge von Zuweisungen soll die Entwicklung einer Population beschreiben. Beurteilen Sie die Wahl der Variablenbezeichner.
# 3. Die Population soll aus zwei Altersklassen bestehen. Beschreiben Sie das hier benutzte Fortpflanzungsmodell mit einem geeigneten Diagramm.
